# %% [markdown]
# # **Say "Hello, World!" With Python**

# %% [markdown]
# ![image.png](attachment:02e5ec7d-12d0-4b43-95c4-6bdd4dc7e04e.png)

# %% [markdown]
# # **🛠️ Solution:**

# %%
print("Hello, World!")
# Out:
# Hello, World!
